# %%
import numpy as np
import pandas as pd

# %%
# !ls

# %%
# read in phenotypes
bed = pd.read_csv('integrated_call_samples_v3.20130502.ALL.panel', delimiter='\t')

# %%
bed.head()
# Out:
#     sample  pop super_pop  gender  Unnamed: 4  Unnamed: 5
# 0  HG00096  GBR       EUR    male         NaN         NaN
# 1  HG00097  GBR       EUR  female         NaN         NaN
# 2  HG00099  GBR       EUR  female         NaN         NaN
# 3  HG00100  GBR       EUR  female         NaN         NaN
# 4  HG00101  GBR       EUR    male         NaN         NaN

# %%
sample_to_super_pop = {k:v for k, v in zip(bed['sample'], bed['super_pop'])}

# %%
# import json
# json.dump(sample_to_super_pop, open('ancestry-tool/app/tests/sample_to_population'))

# %%
# # no maf
# eig_vecs = pd.read_csv('sandbox/plink_mac/test.pca.eigenvec', header=None, delimiter=' ')
# eig_vals = pd.read_csv('sandbox/plink_mac/test.pca.eigenval', header=None)

# # #-maf 5
# eig_vecs = pd.read_csv('sandbox/plink_mac/chr-22-maf-5.pca.eigenvec', header=None, delimiter=' ')
# eig_vals = pd.read_csv('sandbox/plink_mac/chr-22-maf-5.pca.eigenval', header=None)

# #-maf 15
# eig_vecs = pd.read_csv('sandbox/plink_mac/chr-22-maf-15.pca.eigenvec', header=None, delimiter=' ')
# eig_vals = pd.read_csv('sandbox/plink_mac/chr-22-maf-15.pca.eigenval', header=None)

# chr22
# eig_vecs = pd.read_csv('ancestry-tool/app/outputs/chr22.eigenvec', header=None, delimiter=' ')
# eig_vals = pd.read_csv('ancestry-tool/app/outputs/chr22.eigenval', header=None)

# chrom 1 w/ position filter
eig_vecs = pd.read_csv('ancestry-tool/app/outputs/chrom1.eigenvec', header=None, delimiter=' ')

# %%
samples = np.asarray(eig_vecs[0])
sample_to_index = {s:i for i, s in enumerate(eig_vecs[0])}
eig_vecs = np.asarray(eig_vecs.loc[:, 2:])
# eig_vals = np.asarray(eig_vals)

# %%
eig_vecs.shape, eig_vals.shape
# Out:
# ((2504, 5), (5, 1))

# %%
# eig_vals_diag = np.diagflat(eig_vals)

# %%
# pca = np.matmul(eig_vecs, eig_vals_diag)

# %%
# pca.shape

# %%
eig_vecs
# Out:
# array([[ 0.00679719, -0.0224744 , -0.00109167, ..., -0.0235258 ,
#         -0.0125606 ,  0.00116446],
#        [ 0.0119225 , -0.0286319 , -0.0157842 , ..., -0.0216397 ,
#          0.0295615 ,  0.0108487 ],
#        [ 0.0152528 , -0.0281832 , -0.0202455 , ...,  0.00114828,
#          0.0210637 ,  0.0135273 ],
#        ...,
#        [ 0.00737602, -0.0212323 ,  0.0275384 , ...,  0.00098836,
#         -0.0157846 , -0.0286417 ],
#        [ 0.00630389, -0.0120153 ,  0.0141712 , ...,  0.0179593 ,
#          0.0298364 ,  0.0150668 ],
#        [ 0.0142058 ,  0.00211852,  0.00536479, ...,  0.00529252,
#         -0.019193  ,  0.0197921 ]])

# %%
df = pd.DataFrame(eig_vecs)

# %%
super_pop_to_color = {'EUR': 'red', 'EAS': 'blue', 'AMR': 'green', 'AFR': 'yellow', 'SAS': 'pink'}
colors = [super_pop_to_color[sample_to_super_pop[s]] for s in samples]

# %%
pd.scatter_matrix(df.loc[:, :5], color=colors[:], figsize=(12,12))
# Out:
# /Users/estorrs/Documents/ding/ancestry/sandbox/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114478320>,
# ...
#       dtype=object)

# %%
pd.scatter_matrix(df.loc[:, :5], color=colors[:], figsize=(12,12))
# Out:
# /Users/estorrs/Documents/ding/ancestry/sandbox/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x121db4c50>,
# ...
#       dtype=object)

# %%
pd.scatter_matrix(df.loc[:, :5], color=colors[:], figsize=(12,12))
# Out:
# /Users/estorrs/Documents/ding/ancestry/sandbox/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d7db908>,
# ...
#       dtype=object)
